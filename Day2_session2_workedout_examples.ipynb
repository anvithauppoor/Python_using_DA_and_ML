# %% [markdown]
# <a href="https://colab.research.google.com/github/anvithauppoor/Python_using_DA_and_ML/blob/master/Day2_session2_workedout_examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Removes all elements of dictionary dict

# %%
dict = {'Name': 'Zara', 'Age': 7};
print("Start Len : %d" %  len(dict))
dict.clear()
print("End Len : %d" %  len(dict))
# Out:
# Start Len : 2
# End Len : 0

# %% [markdown]
# Returns a list of dict's (key, value) tuple pairs

# %%
dict = {'Name': 'Zara', 'Age': 7}
print ("Value : %s" %  dict.items())
# Out:
# Value : dict_items([('Name', 'Zara'), ('Age', 7)])

# %% [markdown]
# Returns a copy of dictionary dict

# %%
dict1 = {'Name': 'Zara', 'Age': 7};
dict2 = dict1.copy()
print ("New Dictinary : %s" %  str(dict2))
# Out:
# New Dictinary : {'Name': 'Zara', 'Age': 7}

# %% [markdown]
# Python Program to Generate a Dictionary that Contains Numbers (between 1 and n) in the Form (x,x*x).

# %%
n=int(input("Enter a number:"))
d={x:x*x for x in range(1,n+1)}
print(d)
# Out:
# Enter a number:4
# {1: 1, 2: 4, 3: 9, 4: 16}

# %% [markdown]
# Python Program to Sum All the Items in a Dictionary

# %%
d={'A':100,'B':540,'C':239}
print("Total sum of values in the dictionary:")
print(sum(d.values()))
# Out:
# Total sum of values in the dictionary:
# 879

# %% [markdown]
# Python Program to Remove the Given Key from a Dictionary

# %%
d = {'a':1,'b':2,'c':3,'d':4}
print("Initial dictionary")
print(d)
key=input("Enter the key to delete(a-d):")
if key in d: 
  del d[key]
else:
  print("Key not found!")
  exit(0)
print("Updated dictionary")
print(d)
# Out:
# Initial dictionary
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}
# Enter the key to delete(a-d):d
# Updated dictionary
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# Python Program to add name and mark as key->value pair in  a Dictionary and print it.

# %%
n=int(input("Enter no of records"))
d={}
for i in range(1,n+1):
  name= input("Enter name %d"%(i))
  mark=int(input("Enter mark %d"%(i)))
  d[name]=mark
print (d)
# Out:
# Enter no of records3
# Enter name 1anvi
# Enter mark 178
# Enter name 2anu
# Enter mark 276
# Enter name 3appi
# Enter mark 398
# {'anvi': 78, 'anu': 76, 'appi': 98}

# %% [markdown]
# Keys and Values example

# %%
d={}
print (" The dictionary elements are")
for i in range(1,21):
  d[i]=i**2
  print (d)
  # To print key and values
  print (" Key==> Value are")
  for (k,v) in d.items():	
    print(k,"==>",v)
    # To print key only
    print ("\nTo print key only")
    for k in d.keys():	
      print(k, end="")
      #To print value only
      print ("\nTo print values only")
      for v in d.values():	
        print(v, end="")
# Out:
# Streaming output truncated to the last 5000 lines.
# 1491625364964811001211447
# To print values only
# 1491625364964811001211448
# To print values only
# 1491625364964811001211449
# To print values only
# 14916253649648110012114410
# To print values only
# 14916253649648110012114411
# To print values only
# 14916253649648110012114412
# To print values only
# 1491625364964811001211448 ==> 64
#
# To print key only
# 1
# To print values only
# 1491625364964811001211442
# To print values only
# 1491625364964811001211443
# To print values only
# 1491625364964811001211444
# To print values only
# 1491625364964811001211445
# To print values only
# 1491625364964811001211446
# To print values only
# 1491625364964811001211447
# To print values only
# 1491625364964811001211448
# To print values only
# 1491625364964811001211449
# To print values only
# 14916253649648110012114410
# To print values only
# 14916253649648110012114411
# To print values only
# 14916253649648110012114412
# To print values only
# 1491625364964811001211449 ==> 81
#
# To print key only
# 1
# To print values only
# 1491625364964811001211442
# To print values only
# 1491625364964811001211443
# To print values only
# 1491625364964811001211444
# To print values only
# 1491625364964811001211445
# To print values only
# 1491625364964811001211446
# To print values only
# 1491625364964811001211447
# To print values only
# 1491625364964811001211448
# To print values only
# 1491625364964811001211449
# To print values only
# 14916253649648110012114410
# To print values only
# 14916253649648110012114411
# To print values only
# 14916253649648110012114412
# To print values only
# 14916253649648110012114410 ==> 100
#
# To print key only
# 1
# To print values only
# 1491625364964811001211442
# To print values only
# 1491625364964811001211443
# To print values only
# 1491625364964811001211444
# To print values only
# 1491625364964811001211445
# To print values only
# 1491625364964811001211446
# To print values only
# 1491625364964811001211447
# To print values only
# 1491625364964811001211448
# To print values only
# 1491625364964811001211449
# To print values only
# 14916253649648110012114410
# To print values only
# 14916253649648110012114411
# To print values only
# 14916253649648110012114412
# To print values only
# 14916253649648110012114411 ==> 121
#
# To print key only
# 1
# To print values only
# 1491625364964811001211442
# To print values only
# 1491625364964811001211443
# To print values only
# 1491625364964811001211444
# To print values only
# 1491625364964811001211445
# To print values only
# 1491625364964811001211446
# To print values only
# 1491625364964811001211447
# To print values only
# 1491625364964811001211448
# To print values only
# 1491625364964811001211449
# To print values only
# 14916253649648110012114410
# To print values only
# 14916253649648110012114411
# To print values only
# 14916253649648110012114412
# To print values only
# 14916253649648110012114412 ==> 144
#
# To print key only
# 1
# To print values only
# 1491625364964811001211442
# To print values only
# 1491625364964811001211443
# To print values only
# 1491625364964811001211444
# To print values only
# 1491625364964811001211445
# To print values only
# 1491625364964811001211446
# To print values only
# 1491625364964811001211447
# To print values only
# 1491625364964811001211448
# To print values only
# 1491625364964811001211449
# To print values only
# 14916253649648110012114410
# To print values only
# 14916253649648110012114411
# To print values only
# 14916253649648110012114412
# To print values only
# 149162536496481100121144{1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169}
#  Key==> Value are
# 1 ==> 1
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441692
# To print values only
# 1491625364964811001211441693
# To print values only
# 1491625364964811001211441694
# To print values only
# 1491625364964811001211441695
# To print values only
# 1491625364964811001211441696
# To print values only
# 1491625364964811001211441697
# To print values only
# 1491625364964811001211441698
# To print values only
# 1491625364964811001211441699
# To print values only
# 14916253649648110012114416910
# To print values only
# 14916253649648110012114416911
# To print values only
# 14916253649648110012114416912
# To print values only
# 14916253649648110012114416913
# To print values only
# 1491625364964811001211441692 ==> 4
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441692
# To print values only
# 1491625364964811001211441693
# To print values only
# 1491625364964811001211441694
# To print values only
# 1491625364964811001211441695
# To print values only
# 1491625364964811001211441696
# To print values only
# 1491625364964811001211441697
# To print values only
# 1491625364964811001211441698
# To print values only
# 1491625364964811001211441699
# To print values only
# 14916253649648110012114416910
# To print values only
# 14916253649648110012114416911
# To print values only
# 14916253649648110012114416912
# To print values only
# 14916253649648110012114416913
# To print values only
# 1491625364964811001211441693 ==> 9
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441692
# To print values only
# 1491625364964811001211441693
# To print values only
# 1491625364964811001211441694
# To print values only
# 1491625364964811001211441695
# To print values only
# 1491625364964811001211441696
# To print values only
# 1491625364964811001211441697
# To print values only
# 1491625364964811001211441698
# To print values only
# 1491625364964811001211441699
# To print values only
# 14916253649648110012114416910
# To print values only
# 14916253649648110012114416911
# To print values only
# 14916253649648110012114416912
# To print values only
# 14916253649648110012114416913
# To print values only
# 1491625364964811001211441694 ==> 16
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441692
# To print values only
# 1491625364964811001211441693
# To print values only
# 1491625364964811001211441694
# To print values only
# 1491625364964811001211441695
# To print values only
# 1491625364964811001211441696
# To print values only
# 1491625364964811001211441697
# To print values only
# 1491625364964811001211441698
# To print values only
# 1491625364964811001211441699
# To print values only
# 14916253649648110012114416910
# To print values only
# 14916253649648110012114416911
# To print values only
# 14916253649648110012114416912
# To print values only
# 14916253649648110012114416913
# To print values only
# 1491625364964811001211441695 ==> 25
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441692
# To print values only
# 1491625364964811001211441693
# To print values only
# 1491625364964811001211441694
# To print values only
# 1491625364964811001211441695
# To print values only
# 1491625364964811001211441696
# To print values only
# 1491625364964811001211441697
# To print values only
# 1491625364964811001211441698
# To print values only
# 1491625364964811001211441699
# To print values only
# 14916253649648110012114416910
# To print values only
# 14916253649648110012114416911
# To print values only
# 14916253649648110012114416912
# To print values only
# 14916253649648110012114416913
# To print values only
# 1491625364964811001211441696 ==> 36
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441692
# To print values only
# 1491625364964811001211441693
# To print values only
# 1491625364964811001211441694
# To print values only
# 1491625364964811001211441695
# To print values only
# 1491625364964811001211441696
# To print values only
# 1491625364964811001211441697
# To print values only
# 1491625364964811001211441698
# To print values only
# 1491625364964811001211441699
# To print values only
# 14916253649648110012114416910
# To print values only
# 14916253649648110012114416911
# To print values only
# 14916253649648110012114416912
# To print values only
# 14916253649648110012114416913
# To print values only
# 1491625364964811001211441697 ==> 49
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441692
# To print values only
# 1491625364964811001211441693
# To print values only
# 1491625364964811001211441694
# To print values only
# 1491625364964811001211441695
# To print values only
# 1491625364964811001211441696
# To print values only
# 1491625364964811001211441697
# To print values only
# 1491625364964811001211441698
# To print values only
# 1491625364964811001211441699
# To print values only
# 14916253649648110012114416910
# To print values only
# 14916253649648110012114416911
# To print values only
# 14916253649648110012114416912
# To print values only
# 14916253649648110012114416913
# To print values only
# 1491625364964811001211441698 ==> 64
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441692
# To print values only
# 1491625364964811001211441693
# To print values only
# 1491625364964811001211441694
# To print values only
# 1491625364964811001211441695
# To print values only
# 1491625364964811001211441696
# To print values only
# 1491625364964811001211441697
# To print values only
# 1491625364964811001211441698
# To print values only
# 1491625364964811001211441699
# To print values only
# 14916253649648110012114416910
# To print values only
# 14916253649648110012114416911
# To print values only
# 14916253649648110012114416912
# To print values only
# 14916253649648110012114416913
# To print values only
# 1491625364964811001211441699 ==> 81
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441692
# To print values only
# 1491625364964811001211441693
# To print values only
# 1491625364964811001211441694
# To print values only
# 1491625364964811001211441695
# To print values only
# 1491625364964811001211441696
# To print values only
# 1491625364964811001211441697
# To print values only
# 1491625364964811001211441698
# To print values only
# 1491625364964811001211441699
# To print values only
# 14916253649648110012114416910
# To print values only
# 14916253649648110012114416911
# To print values only
# 14916253649648110012114416912
# To print values only
# 14916253649648110012114416913
# To print values only
# 14916253649648110012114416910 ==> 100
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441692
# To print values only
# 1491625364964811001211441693
# To print values only
# 1491625364964811001211441694
# To print values only
# 1491625364964811001211441695
# To print values only
# 1491625364964811001211441696
# To print values only
# 1491625364964811001211441697
# To print values only
# 1491625364964811001211441698
# To print values only
# 1491625364964811001211441699
# To print values only
# 14916253649648110012114416910
# To print values only
# 14916253649648110012114416911
# To print values only
# 14916253649648110012114416912
# To print values only
# 14916253649648110012114416913
# To print values only
# 14916253649648110012114416911 ==> 121
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441692
# To print values only
# 1491625364964811001211441693
# To print values only
# 1491625364964811001211441694
# To print values only
# 1491625364964811001211441695
# To print values only
# 1491625364964811001211441696
# To print values only
# 1491625364964811001211441697
# To print values only
# 1491625364964811001211441698
# To print values only
# 1491625364964811001211441699
# To print values only
# 14916253649648110012114416910
# To print values only
# 14916253649648110012114416911
# To print values only
# 14916253649648110012114416912
# To print values only
# 14916253649648110012114416913
# To print values only
# 14916253649648110012114416912 ==> 144
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441692
# To print values only
# 1491625364964811001211441693
# To print values only
# 1491625364964811001211441694
# To print values only
# 1491625364964811001211441695
# To print values only
# 1491625364964811001211441696
# To print values only
# 1491625364964811001211441697
# To print values only
# 1491625364964811001211441698
# To print values only
# 1491625364964811001211441699
# To print values only
# 14916253649648110012114416910
# To print values only
# 14916253649648110012114416911
# To print values only
# 14916253649648110012114416912
# To print values only
# 14916253649648110012114416913
# To print values only
# 14916253649648110012114416913 ==> 169
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441692
# To print values only
# 1491625364964811001211441693
# To print values only
# 1491625364964811001211441694
# To print values only
# 1491625364964811001211441695
# To print values only
# 1491625364964811001211441696
# To print values only
# 1491625364964811001211441697
# To print values only
# 1491625364964811001211441698
# To print values only
# 1491625364964811001211441699
# To print values only
# 14916253649648110012114416910
# To print values only
# 14916253649648110012114416911
# To print values only
# 14916253649648110012114416912
# To print values only
# 14916253649648110012114416913
# To print values only
# 149162536496481100121144169{1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196}
#  Key==> Value are
# 1 ==> 1
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962
# To print values only
# 1491625364964811001211441691963
# To print values only
# 1491625364964811001211441691964
# To print values only
# 1491625364964811001211441691965
# To print values only
# 1491625364964811001211441691966
# To print values only
# 1491625364964811001211441691967
# To print values only
# 1491625364964811001211441691968
# To print values only
# 1491625364964811001211441691969
# To print values only
# 14916253649648110012114416919610
# To print values only
# 14916253649648110012114416919611
# To print values only
# 14916253649648110012114416919612
# To print values only
# 14916253649648110012114416919613
# To print values only
# 14916253649648110012114416919614
# To print values only
# 1491625364964811001211441691962 ==> 4
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962
# To print values only
# 1491625364964811001211441691963
# To print values only
# 1491625364964811001211441691964
# To print values only
# 1491625364964811001211441691965
# To print values only
# 1491625364964811001211441691966
# To print values only
# 1491625364964811001211441691967
# To print values only
# 1491625364964811001211441691968
# To print values only
# 1491625364964811001211441691969
# To print values only
# 14916253649648110012114416919610
# To print values only
# 14916253649648110012114416919611
# To print values only
# 14916253649648110012114416919612
# To print values only
# 14916253649648110012114416919613
# To print values only
# 14916253649648110012114416919614
# To print values only
# 1491625364964811001211441691963 ==> 9
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962
# To print values only
# 1491625364964811001211441691963
# To print values only
# 1491625364964811001211441691964
# To print values only
# 1491625364964811001211441691965
# To print values only
# 1491625364964811001211441691966
# To print values only
# 1491625364964811001211441691967
# To print values only
# 1491625364964811001211441691968
# To print values only
# 1491625364964811001211441691969
# To print values only
# 14916253649648110012114416919610
# To print values only
# 14916253649648110012114416919611
# To print values only
# 14916253649648110012114416919612
# To print values only
# 14916253649648110012114416919613
# To print values only
# 14916253649648110012114416919614
# To print values only
# 1491625364964811001211441691964 ==> 16
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962
# To print values only
# 1491625364964811001211441691963
# To print values only
# 1491625364964811001211441691964
# To print values only
# 1491625364964811001211441691965
# To print values only
# 1491625364964811001211441691966
# To print values only
# 1491625364964811001211441691967
# To print values only
# 1491625364964811001211441691968
# To print values only
# 1491625364964811001211441691969
# To print values only
# 14916253649648110012114416919610
# To print values only
# 14916253649648110012114416919611
# To print values only
# 14916253649648110012114416919612
# To print values only
# 14916253649648110012114416919613
# To print values only
# 14916253649648110012114416919614
# To print values only
# 1491625364964811001211441691965 ==> 25
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962
# To print values only
# 1491625364964811001211441691963
# To print values only
# 1491625364964811001211441691964
# To print values only
# 1491625364964811001211441691965
# To print values only
# 1491625364964811001211441691966
# To print values only
# 1491625364964811001211441691967
# To print values only
# 1491625364964811001211441691968
# To print values only
# 1491625364964811001211441691969
# To print values only
# 14916253649648110012114416919610
# To print values only
# 14916253649648110012114416919611
# To print values only
# 14916253649648110012114416919612
# To print values only
# 14916253649648110012114416919613
# To print values only
# 14916253649648110012114416919614
# To print values only
# 1491625364964811001211441691966 ==> 36
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962
# To print values only
# 1491625364964811001211441691963
# To print values only
# 1491625364964811001211441691964
# To print values only
# 1491625364964811001211441691965
# To print values only
# 1491625364964811001211441691966
# To print values only
# 1491625364964811001211441691967
# To print values only
# 1491625364964811001211441691968
# To print values only
# 1491625364964811001211441691969
# To print values only
# 14916253649648110012114416919610
# To print values only
# 14916253649648110012114416919611
# To print values only
# 14916253649648110012114416919612
# To print values only
# 14916253649648110012114416919613
# To print values only
# 14916253649648110012114416919614
# To print values only
# 1491625364964811001211441691967 ==> 49
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962
# To print values only
# 1491625364964811001211441691963
# To print values only
# 1491625364964811001211441691964
# To print values only
# 1491625364964811001211441691965
# To print values only
# 1491625364964811001211441691966
# To print values only
# 1491625364964811001211441691967
# To print values only
# 1491625364964811001211441691968
# To print values only
# 1491625364964811001211441691969
# To print values only
# 14916253649648110012114416919610
# To print values only
# 14916253649648110012114416919611
# To print values only
# 14916253649648110012114416919612
# To print values only
# 14916253649648110012114416919613
# To print values only
# 14916253649648110012114416919614
# To print values only
# 1491625364964811001211441691968 ==> 64
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962
# To print values only
# 1491625364964811001211441691963
# To print values only
# 1491625364964811001211441691964
# To print values only
# 1491625364964811001211441691965
# To print values only
# 1491625364964811001211441691966
# To print values only
# 1491625364964811001211441691967
# To print values only
# 1491625364964811001211441691968
# To print values only
# 1491625364964811001211441691969
# To print values only
# 14916253649648110012114416919610
# To print values only
# 14916253649648110012114416919611
# To print values only
# 14916253649648110012114416919612
# To print values only
# 14916253649648110012114416919613
# To print values only
# 14916253649648110012114416919614
# To print values only
# 1491625364964811001211441691969 ==> 81
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962
# To print values only
# 1491625364964811001211441691963
# To print values only
# 1491625364964811001211441691964
# To print values only
# 1491625364964811001211441691965
# To print values only
# 1491625364964811001211441691966
# To print values only
# 1491625364964811001211441691967
# To print values only
# 1491625364964811001211441691968
# To print values only
# 1491625364964811001211441691969
# To print values only
# 14916253649648110012114416919610
# To print values only
# 14916253649648110012114416919611
# To print values only
# 14916253649648110012114416919612
# To print values only
# 14916253649648110012114416919613
# To print values only
# 14916253649648110012114416919614
# To print values only
# 14916253649648110012114416919610 ==> 100
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962
# To print values only
# 1491625364964811001211441691963
# To print values only
# 1491625364964811001211441691964
# To print values only
# 1491625364964811001211441691965
# To print values only
# 1491625364964811001211441691966
# To print values only
# 1491625364964811001211441691967
# To print values only
# 1491625364964811001211441691968
# To print values only
# 1491625364964811001211441691969
# To print values only
# 14916253649648110012114416919610
# To print values only
# 14916253649648110012114416919611
# To print values only
# 14916253649648110012114416919612
# To print values only
# 14916253649648110012114416919613
# To print values only
# 14916253649648110012114416919614
# To print values only
# 14916253649648110012114416919611 ==> 121
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962
# To print values only
# 1491625364964811001211441691963
# To print values only
# 1491625364964811001211441691964
# To print values only
# 1491625364964811001211441691965
# To print values only
# 1491625364964811001211441691966
# To print values only
# 1491625364964811001211441691967
# To print values only
# 1491625364964811001211441691968
# To print values only
# 1491625364964811001211441691969
# To print values only
# 14916253649648110012114416919610
# To print values only
# 14916253649648110012114416919611
# To print values only
# 14916253649648110012114416919612
# To print values only
# 14916253649648110012114416919613
# To print values only
# 14916253649648110012114416919614
# To print values only
# 14916253649648110012114416919612 ==> 144
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962
# To print values only
# 1491625364964811001211441691963
# To print values only
# 1491625364964811001211441691964
# To print values only
# 1491625364964811001211441691965
# To print values only
# 1491625364964811001211441691966
# To print values only
# 1491625364964811001211441691967
# To print values only
# 1491625364964811001211441691968
# To print values only
# 1491625364964811001211441691969
# To print values only
# 14916253649648110012114416919610
# To print values only
# 14916253649648110012114416919611
# To print values only
# 14916253649648110012114416919612
# To print values only
# 14916253649648110012114416919613
# To print values only
# 14916253649648110012114416919614
# To print values only
# 14916253649648110012114416919613 ==> 169
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962
# To print values only
# 1491625364964811001211441691963
# To print values only
# 1491625364964811001211441691964
# To print values only
# 1491625364964811001211441691965
# To print values only
# 1491625364964811001211441691966
# To print values only
# 1491625364964811001211441691967
# To print values only
# 1491625364964811001211441691968
# To print values only
# 1491625364964811001211441691969
# To print values only
# 14916253649648110012114416919610
# To print values only
# 14916253649648110012114416919611
# To print values only
# 14916253649648110012114416919612
# To print values only
# 14916253649648110012114416919613
# To print values only
# 14916253649648110012114416919614
# To print values only
# 14916253649648110012114416919614 ==> 196
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962
# To print values only
# 1491625364964811001211441691963
# To print values only
# 1491625364964811001211441691964
# To print values only
# 1491625364964811001211441691965
# To print values only
# 1491625364964811001211441691966
# To print values only
# 1491625364964811001211441691967
# To print values only
# 1491625364964811001211441691968
# To print values only
# 1491625364964811001211441691969
# To print values only
# 14916253649648110012114416919610
# To print values only
# 14916253649648110012114416919611
# To print values only
# 14916253649648110012114416919612
# To print values only
# 14916253649648110012114416919613
# To print values only
# 14916253649648110012114416919614
# To print values only
# 149162536496481100121144169196{1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}
#  Key==> Value are
# 1 ==> 1
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252
# To print values only
# 1491625364964811001211441691962253
# To print values only
# 1491625364964811001211441691962254
# To print values only
# 1491625364964811001211441691962255
# To print values only
# 1491625364964811001211441691962256
# To print values only
# 1491625364964811001211441691962257
# To print values only
# 1491625364964811001211441691962258
# To print values only
# 1491625364964811001211441691962259
# To print values only
# 14916253649648110012114416919622510
# To print values only
# 14916253649648110012114416919622511
# To print values only
# 14916253649648110012114416919622512
# To print values only
# 14916253649648110012114416919622513
# To print values only
# 14916253649648110012114416919622514
# To print values only
# 14916253649648110012114416919622515
# To print values only
# 1491625364964811001211441691962252 ==> 4
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252
# To print values only
# 1491625364964811001211441691962253
# To print values only
# 1491625364964811001211441691962254
# To print values only
# 1491625364964811001211441691962255
# To print values only
# 1491625364964811001211441691962256
# To print values only
# 1491625364964811001211441691962257
# To print values only
# 1491625364964811001211441691962258
# To print values only
# 1491625364964811001211441691962259
# To print values only
# 14916253649648110012114416919622510
# To print values only
# 14916253649648110012114416919622511
# To print values only
# 14916253649648110012114416919622512
# To print values only
# 14916253649648110012114416919622513
# To print values only
# 14916253649648110012114416919622514
# To print values only
# 14916253649648110012114416919622515
# To print values only
# 1491625364964811001211441691962253 ==> 9
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252
# To print values only
# 1491625364964811001211441691962253
# To print values only
# 1491625364964811001211441691962254
# To print values only
# 1491625364964811001211441691962255
# To print values only
# 1491625364964811001211441691962256
# To print values only
# 1491625364964811001211441691962257
# To print values only
# 1491625364964811001211441691962258
# To print values only
# 1491625364964811001211441691962259
# To print values only
# 14916253649648110012114416919622510
# To print values only
# 14916253649648110012114416919622511
# To print values only
# 14916253649648110012114416919622512
# To print values only
# 14916253649648110012114416919622513
# To print values only
# 14916253649648110012114416919622514
# To print values only
# 14916253649648110012114416919622515
# To print values only
# 1491625364964811001211441691962254 ==> 16
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252
# To print values only
# 1491625364964811001211441691962253
# To print values only
# 1491625364964811001211441691962254
# To print values only
# 1491625364964811001211441691962255
# To print values only
# 1491625364964811001211441691962256
# To print values only
# 1491625364964811001211441691962257
# To print values only
# 1491625364964811001211441691962258
# To print values only
# 1491625364964811001211441691962259
# To print values only
# 14916253649648110012114416919622510
# To print values only
# 14916253649648110012114416919622511
# To print values only
# 14916253649648110012114416919622512
# To print values only
# 14916253649648110012114416919622513
# To print values only
# 14916253649648110012114416919622514
# To print values only
# 14916253649648110012114416919622515
# To print values only
# 1491625364964811001211441691962255 ==> 25
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252
# To print values only
# 1491625364964811001211441691962253
# To print values only
# 1491625364964811001211441691962254
# To print values only
# 1491625364964811001211441691962255
# To print values only
# 1491625364964811001211441691962256
# To print values only
# 1491625364964811001211441691962257
# To print values only
# 1491625364964811001211441691962258
# To print values only
# 1491625364964811001211441691962259
# To print values only
# 14916253649648110012114416919622510
# To print values only
# 14916253649648110012114416919622511
# To print values only
# 14916253649648110012114416919622512
# To print values only
# 14916253649648110012114416919622513
# To print values only
# 14916253649648110012114416919622514
# To print values only
# 14916253649648110012114416919622515
# To print values only
# 1491625364964811001211441691962256 ==> 36
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252
# To print values only
# 1491625364964811001211441691962253
# To print values only
# 1491625364964811001211441691962254
# To print values only
# 1491625364964811001211441691962255
# To print values only
# 1491625364964811001211441691962256
# To print values only
# 1491625364964811001211441691962257
# To print values only
# 1491625364964811001211441691962258
# To print values only
# 1491625364964811001211441691962259
# To print values only
# 14916253649648110012114416919622510
# To print values only
# 14916253649648110012114416919622511
# To print values only
# 14916253649648110012114416919622512
# To print values only
# 14916253649648110012114416919622513
# To print values only
# 14916253649648110012114416919622514
# To print values only
# 14916253649648110012114416919622515
# To print values only
# 1491625364964811001211441691962257 ==> 49
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252
# To print values only
# 1491625364964811001211441691962253
# To print values only
# 1491625364964811001211441691962254
# To print values only
# 1491625364964811001211441691962255
# To print values only
# 1491625364964811001211441691962256
# To print values only
# 1491625364964811001211441691962257
# To print values only
# 1491625364964811001211441691962258
# To print values only
# 1491625364964811001211441691962259
# To print values only
# 14916253649648110012114416919622510
# To print values only
# 14916253649648110012114416919622511
# To print values only
# 14916253649648110012114416919622512
# To print values only
# 14916253649648110012114416919622513
# To print values only
# 14916253649648110012114416919622514
# To print values only
# 14916253649648110012114416919622515
# To print values only
# 1491625364964811001211441691962258 ==> 64
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252
# To print values only
# 1491625364964811001211441691962253
# To print values only
# 1491625364964811001211441691962254
# To print values only
# 1491625364964811001211441691962255
# To print values only
# 1491625364964811001211441691962256
# To print values only
# 1491625364964811001211441691962257
# To print values only
# 1491625364964811001211441691962258
# To print values only
# 1491625364964811001211441691962259
# To print values only
# 14916253649648110012114416919622510
# To print values only
# 14916253649648110012114416919622511
# To print values only
# 14916253649648110012114416919622512
# To print values only
# 14916253649648110012114416919622513
# To print values only
# 14916253649648110012114416919622514
# To print values only
# 14916253649648110012114416919622515
# To print values only
# 1491625364964811001211441691962259 ==> 81
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252
# To print values only
# 1491625364964811001211441691962253
# To print values only
# 1491625364964811001211441691962254
# To print values only
# 1491625364964811001211441691962255
# To print values only
# 1491625364964811001211441691962256
# To print values only
# 1491625364964811001211441691962257
# To print values only
# 1491625364964811001211441691962258
# To print values only
# 1491625364964811001211441691962259
# To print values only
# 14916253649648110012114416919622510
# To print values only
# 14916253649648110012114416919622511
# To print values only
# 14916253649648110012114416919622512
# To print values only
# 14916253649648110012114416919622513
# To print values only
# 14916253649648110012114416919622514
# To print values only
# 14916253649648110012114416919622515
# To print values only
# 14916253649648110012114416919622510 ==> 100
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252
# To print values only
# 1491625364964811001211441691962253
# To print values only
# 1491625364964811001211441691962254
# To print values only
# 1491625364964811001211441691962255
# To print values only
# 1491625364964811001211441691962256
# To print values only
# 1491625364964811001211441691962257
# To print values only
# 1491625364964811001211441691962258
# To print values only
# 1491625364964811001211441691962259
# To print values only
# 14916253649648110012114416919622510
# To print values only
# 14916253649648110012114416919622511
# To print values only
# 14916253649648110012114416919622512
# To print values only
# 14916253649648110012114416919622513
# To print values only
# 14916253649648110012114416919622514
# To print values only
# 14916253649648110012114416919622515
# To print values only
# 14916253649648110012114416919622511 ==> 121
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252
# To print values only
# 1491625364964811001211441691962253
# To print values only
# 1491625364964811001211441691962254
# To print values only
# 1491625364964811001211441691962255
# To print values only
# 1491625364964811001211441691962256
# To print values only
# 1491625364964811001211441691962257
# To print values only
# 1491625364964811001211441691962258
# To print values only
# 1491625364964811001211441691962259
# To print values only
# 14916253649648110012114416919622510
# To print values only
# 14916253649648110012114416919622511
# To print values only
# 14916253649648110012114416919622512
# To print values only
# 14916253649648110012114416919622513
# To print values only
# 14916253649648110012114416919622514
# To print values only
# 14916253649648110012114416919622515
# To print values only
# 14916253649648110012114416919622512 ==> 144
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252
# To print values only
# 1491625364964811001211441691962253
# To print values only
# 1491625364964811001211441691962254
# To print values only
# 1491625364964811001211441691962255
# To print values only
# 1491625364964811001211441691962256
# To print values only
# 1491625364964811001211441691962257
# To print values only
# 1491625364964811001211441691962258
# To print values only
# 1491625364964811001211441691962259
# To print values only
# 14916253649648110012114416919622510
# To print values only
# 14916253649648110012114416919622511
# To print values only
# 14916253649648110012114416919622512
# To print values only
# 14916253649648110012114416919622513
# To print values only
# 14916253649648110012114416919622514
# To print values only
# 14916253649648110012114416919622515
# To print values only
# 14916253649648110012114416919622513 ==> 169
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252
# To print values only
# 1491625364964811001211441691962253
# To print values only
# 1491625364964811001211441691962254
# To print values only
# 1491625364964811001211441691962255
# To print values only
# 1491625364964811001211441691962256
# To print values only
# 1491625364964811001211441691962257
# To print values only
# 1491625364964811001211441691962258
# To print values only
# 1491625364964811001211441691962259
# To print values only
# 14916253649648110012114416919622510
# To print values only
# 14916253649648110012114416919622511
# To print values only
# 14916253649648110012114416919622512
# To print values only
# 14916253649648110012114416919622513
# To print values only
# 14916253649648110012114416919622514
# To print values only
# 14916253649648110012114416919622515
# To print values only
# 14916253649648110012114416919622514 ==> 196
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252
# To print values only
# 1491625364964811001211441691962253
# To print values only
# 1491625364964811001211441691962254
# To print values only
# 1491625364964811001211441691962255
# To print values only
# 1491625364964811001211441691962256
# To print values only
# 1491625364964811001211441691962257
# To print values only
# 1491625364964811001211441691962258
# To print values only
# 1491625364964811001211441691962259
# To print values only
# 14916253649648110012114416919622510
# To print values only
# 14916253649648110012114416919622511
# To print values only
# 14916253649648110012114416919622512
# To print values only
# 14916253649648110012114416919622513
# To print values only
# 14916253649648110012114416919622514
# To print values only
# 14916253649648110012114416919622515
# To print values only
# 14916253649648110012114416919622515 ==> 225
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252
# To print values only
# 1491625364964811001211441691962253
# To print values only
# 1491625364964811001211441691962254
# To print values only
# 1491625364964811001211441691962255
# To print values only
# 1491625364964811001211441691962256
# To print values only
# 1491625364964811001211441691962257
# To print values only
# 1491625364964811001211441691962258
# To print values only
# 1491625364964811001211441691962259
# To print values only
# 14916253649648110012114416919622510
# To print values only
# 14916253649648110012114416919622511
# To print values only
# 14916253649648110012114416919622512
# To print values only
# 14916253649648110012114416919622513
# To print values only
# 14916253649648110012114416919622514
# To print values only
# 14916253649648110012114416919622515
# To print values only
# 149162536496481100121144169196225{1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225, 16: 256}
#  Key==> Value are
# 1 ==> 1
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562
# To print values only
# 1491625364964811001211441691962252563
# To print values only
# 1491625364964811001211441691962252564
# To print values only
# 1491625364964811001211441691962252565
# To print values only
# 1491625364964811001211441691962252566
# To print values only
# 1491625364964811001211441691962252567
# To print values only
# 1491625364964811001211441691962252568
# To print values only
# 1491625364964811001211441691962252569
# To print values only
# 14916253649648110012114416919622525610
# To print values only
# 14916253649648110012114416919622525611
# To print values only
# 14916253649648110012114416919622525612
# To print values only
# 14916253649648110012114416919622525613
# To print values only
# 14916253649648110012114416919622525614
# To print values only
# 14916253649648110012114416919622525615
# To print values only
# 14916253649648110012114416919622525616
# To print values only
# 1491625364964811001211441691962252562 ==> 4
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562
# To print values only
# 1491625364964811001211441691962252563
# To print values only
# 1491625364964811001211441691962252564
# To print values only
# 1491625364964811001211441691962252565
# To print values only
# 1491625364964811001211441691962252566
# To print values only
# 1491625364964811001211441691962252567
# To print values only
# 1491625364964811001211441691962252568
# To print values only
# 1491625364964811001211441691962252569
# To print values only
# 14916253649648110012114416919622525610
# To print values only
# 14916253649648110012114416919622525611
# To print values only
# 14916253649648110012114416919622525612
# To print values only
# 14916253649648110012114416919622525613
# To print values only
# 14916253649648110012114416919622525614
# To print values only
# 14916253649648110012114416919622525615
# To print values only
# 14916253649648110012114416919622525616
# To print values only
# 1491625364964811001211441691962252563 ==> 9
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562
# To print values only
# 1491625364964811001211441691962252563
# To print values only
# 1491625364964811001211441691962252564
# To print values only
# 1491625364964811001211441691962252565
# To print values only
# 1491625364964811001211441691962252566
# To print values only
# 1491625364964811001211441691962252567
# To print values only
# 1491625364964811001211441691962252568
# To print values only
# 1491625364964811001211441691962252569
# To print values only
# 14916253649648110012114416919622525610
# To print values only
# 14916253649648110012114416919622525611
# To print values only
# 14916253649648110012114416919622525612
# To print values only
# 14916253649648110012114416919622525613
# To print values only
# 14916253649648110012114416919622525614
# To print values only
# 14916253649648110012114416919622525615
# To print values only
# 14916253649648110012114416919622525616
# To print values only
# 1491625364964811001211441691962252564 ==> 16
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562
# To print values only
# 1491625364964811001211441691962252563
# To print values only
# 1491625364964811001211441691962252564
# To print values only
# 1491625364964811001211441691962252565
# To print values only
# 1491625364964811001211441691962252566
# To print values only
# 1491625364964811001211441691962252567
# To print values only
# 1491625364964811001211441691962252568
# To print values only
# 1491625364964811001211441691962252569
# To print values only
# 14916253649648110012114416919622525610
# To print values only
# 14916253649648110012114416919622525611
# To print values only
# 14916253649648110012114416919622525612
# To print values only
# 14916253649648110012114416919622525613
# To print values only
# 14916253649648110012114416919622525614
# To print values only
# 14916253649648110012114416919622525615
# To print values only
# 14916253649648110012114416919622525616
# To print values only
# 1491625364964811001211441691962252565 ==> 25
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562
# To print values only
# 1491625364964811001211441691962252563
# To print values only
# 1491625364964811001211441691962252564
# To print values only
# 1491625364964811001211441691962252565
# To print values only
# 1491625364964811001211441691962252566
# To print values only
# 1491625364964811001211441691962252567
# To print values only
# 1491625364964811001211441691962252568
# To print values only
# 1491625364964811001211441691962252569
# To print values only
# 14916253649648110012114416919622525610
# To print values only
# 14916253649648110012114416919622525611
# To print values only
# 14916253649648110012114416919622525612
# To print values only
# 14916253649648110012114416919622525613
# To print values only
# 14916253649648110012114416919622525614
# To print values only
# 14916253649648110012114416919622525615
# To print values only
# 14916253649648110012114416919622525616
# To print values only
# 1491625364964811001211441691962252566 ==> 36
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562
# To print values only
# 1491625364964811001211441691962252563
# To print values only
# 1491625364964811001211441691962252564
# To print values only
# 1491625364964811001211441691962252565
# To print values only
# 1491625364964811001211441691962252566
# To print values only
# 1491625364964811001211441691962252567
# To print values only
# 1491625364964811001211441691962252568
# To print values only
# 1491625364964811001211441691962252569
# To print values only
# 14916253649648110012114416919622525610
# To print values only
# 14916253649648110012114416919622525611
# To print values only
# 14916253649648110012114416919622525612
# To print values only
# 14916253649648110012114416919622525613
# To print values only
# 14916253649648110012114416919622525614
# To print values only
# 14916253649648110012114416919622525615
# To print values only
# 14916253649648110012114416919622525616
# To print values only
# 1491625364964811001211441691962252567 ==> 49
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562
# To print values only
# 1491625364964811001211441691962252563
# To print values only
# 1491625364964811001211441691962252564
# To print values only
# 1491625364964811001211441691962252565
# To print values only
# 1491625364964811001211441691962252566
# To print values only
# 1491625364964811001211441691962252567
# To print values only
# 1491625364964811001211441691962252568
# To print values only
# 1491625364964811001211441691962252569
# To print values only
# 14916253649648110012114416919622525610
# To print values only
# 14916253649648110012114416919622525611
# To print values only
# 14916253649648110012114416919622525612
# To print values only
# 14916253649648110012114416919622525613
# To print values only
# 14916253649648110012114416919622525614
# To print values only
# 14916253649648110012114416919622525615
# To print values only
# 14916253649648110012114416919622525616
# To print values only
# 1491625364964811001211441691962252568 ==> 64
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562
# To print values only
# 1491625364964811001211441691962252563
# To print values only
# 1491625364964811001211441691962252564
# To print values only
# 1491625364964811001211441691962252565
# To print values only
# 1491625364964811001211441691962252566
# To print values only
# 1491625364964811001211441691962252567
# To print values only
# 1491625364964811001211441691962252568
# To print values only
# 1491625364964811001211441691962252569
# To print values only
# 14916253649648110012114416919622525610
# To print values only
# 14916253649648110012114416919622525611
# To print values only
# 14916253649648110012114416919622525612
# To print values only
# 14916253649648110012114416919622525613
# To print values only
# 14916253649648110012114416919622525614
# To print values only
# 14916253649648110012114416919622525615
# To print values only
# 14916253649648110012114416919622525616
# To print values only
# 1491625364964811001211441691962252569 ==> 81
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562
# To print values only
# 1491625364964811001211441691962252563
# To print values only
# 1491625364964811001211441691962252564
# To print values only
# 1491625364964811001211441691962252565
# To print values only
# 1491625364964811001211441691962252566
# To print values only
# 1491625364964811001211441691962252567
# To print values only
# 1491625364964811001211441691962252568
# To print values only
# 1491625364964811001211441691962252569
# To print values only
# 14916253649648110012114416919622525610
# To print values only
# 14916253649648110012114416919622525611
# To print values only
# 14916253649648110012114416919622525612
# To print values only
# 14916253649648110012114416919622525613
# To print values only
# 14916253649648110012114416919622525614
# To print values only
# 14916253649648110012114416919622525615
# To print values only
# 14916253649648110012114416919622525616
# To print values only
# 14916253649648110012114416919622525610 ==> 100
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562
# To print values only
# 1491625364964811001211441691962252563
# To print values only
# 1491625364964811001211441691962252564
# To print values only
# 1491625364964811001211441691962252565
# To print values only
# 1491625364964811001211441691962252566
# To print values only
# 1491625364964811001211441691962252567
# To print values only
# 1491625364964811001211441691962252568
# To print values only
# 1491625364964811001211441691962252569
# To print values only
# 14916253649648110012114416919622525610
# To print values only
# 14916253649648110012114416919622525611
# To print values only
# 14916253649648110012114416919622525612
# To print values only
# 14916253649648110012114416919622525613
# To print values only
# 14916253649648110012114416919622525614
# To print values only
# 14916253649648110012114416919622525615
# To print values only
# 14916253649648110012114416919622525616
# To print values only
# 14916253649648110012114416919622525611 ==> 121
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562
# To print values only
# 1491625364964811001211441691962252563
# To print values only
# 1491625364964811001211441691962252564
# To print values only
# 1491625364964811001211441691962252565
# To print values only
# 1491625364964811001211441691962252566
# To print values only
# 1491625364964811001211441691962252567
# To print values only
# 1491625364964811001211441691962252568
# To print values only
# 1491625364964811001211441691962252569
# To print values only
# 14916253649648110012114416919622525610
# To print values only
# 14916253649648110012114416919622525611
# To print values only
# 14916253649648110012114416919622525612
# To print values only
# 14916253649648110012114416919622525613
# To print values only
# 14916253649648110012114416919622525614
# To print values only
# 14916253649648110012114416919622525615
# To print values only
# 14916253649648110012114416919622525616
# To print values only
# 14916253649648110012114416919622525612 ==> 144
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562
# To print values only
# 1491625364964811001211441691962252563
# To print values only
# 1491625364964811001211441691962252564
# To print values only
# 1491625364964811001211441691962252565
# To print values only
# 1491625364964811001211441691962252566
# To print values only
# 1491625364964811001211441691962252567
# To print values only
# 1491625364964811001211441691962252568
# To print values only
# 1491625364964811001211441691962252569
# To print values only
# ...
# To print values only
# 1491625364964811001211441691962252562893243614003
# To print values only
# 1491625364964811001211441691962252562893243614004
# To print values only
# 1491625364964811001211441691962252562893243614005
# To print values only
# 1491625364964811001211441691962252562893243614006
# To print values only
# 1491625364964811001211441691962252562893243614007
# To print values only
# 1491625364964811001211441691962252562893243614008
# To print values only
# 1491625364964811001211441691962252562893243614009
# To print values only
# 14916253649648110012114416919622525628932436140010
# To print values only
# 14916253649648110012114416919622525628932436140011
# To print values only
# 14916253649648110012114416919622525628932436140012
# To print values only
# 14916253649648110012114416919622525628932436140013
# To print values only
# 14916253649648110012114416919622525628932436140014
# To print values only
# 14916253649648110012114416919622525628932436140015
# To print values only
# 14916253649648110012114416919622525628932436140016
# To print values only
# 14916253649648110012114416919622525628932436140017
# To print values only
# 14916253649648110012114416919622525628932436140018
# To print values only
# 14916253649648110012114416919622525628932436140019
# To print values only
# 14916253649648110012114416919622525628932436140020
# To print values only
# 14916253649648110012114416919622525628932436140011 ==> 121
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562893243614002
# To print values only
# 1491625364964811001211441691962252562893243614003
# To print values only
# 1491625364964811001211441691962252562893243614004
# To print values only
# 1491625364964811001211441691962252562893243614005
# To print values only
# 1491625364964811001211441691962252562893243614006
# To print values only
# 1491625364964811001211441691962252562893243614007
# To print values only
# 1491625364964811001211441691962252562893243614008
# To print values only
# 1491625364964811001211441691962252562893243614009
# To print values only
# 14916253649648110012114416919622525628932436140010
# To print values only
# 14916253649648110012114416919622525628932436140011
# To print values only
# 14916253649648110012114416919622525628932436140012
# To print values only
# 14916253649648110012114416919622525628932436140013
# To print values only
# 14916253649648110012114416919622525628932436140014
# To print values only
# 14916253649648110012114416919622525628932436140015
# To print values only
# 14916253649648110012114416919622525628932436140016
# To print values only
# 14916253649648110012114416919622525628932436140017
# To print values only
# 14916253649648110012114416919622525628932436140018
# To print values only
# 14916253649648110012114416919622525628932436140019
# To print values only
# 14916253649648110012114416919622525628932436140020
# To print values only
# 14916253649648110012114416919622525628932436140012 ==> 144
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562893243614002
# To print values only
# 1491625364964811001211441691962252562893243614003
# To print values only
# 1491625364964811001211441691962252562893243614004
# To print values only
# 1491625364964811001211441691962252562893243614005
# To print values only
# 1491625364964811001211441691962252562893243614006
# To print values only
# 1491625364964811001211441691962252562893243614007
# To print values only
# 1491625364964811001211441691962252562893243614008
# To print values only
# 1491625364964811001211441691962252562893243614009
# To print values only
# 14916253649648110012114416919622525628932436140010
# To print values only
# 14916253649648110012114416919622525628932436140011
# To print values only
# 14916253649648110012114416919622525628932436140012
# To print values only
# 14916253649648110012114416919622525628932436140013
# To print values only
# 14916253649648110012114416919622525628932436140014
# To print values only
# 14916253649648110012114416919622525628932436140015
# To print values only
# 14916253649648110012114416919622525628932436140016
# To print values only
# 14916253649648110012114416919622525628932436140017
# To print values only
# 14916253649648110012114416919622525628932436140018
# To print values only
# 14916253649648110012114416919622525628932436140019
# To print values only
# 14916253649648110012114416919622525628932436140020
# To print values only
# 14916253649648110012114416919622525628932436140013 ==> 169
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562893243614002
# To print values only
# 1491625364964811001211441691962252562893243614003
# To print values only
# 1491625364964811001211441691962252562893243614004
# To print values only
# 1491625364964811001211441691962252562893243614005
# To print values only
# 1491625364964811001211441691962252562893243614006
# To print values only
# 1491625364964811001211441691962252562893243614007
# To print values only
# 1491625364964811001211441691962252562893243614008
# To print values only
# 1491625364964811001211441691962252562893243614009
# To print values only
# 14916253649648110012114416919622525628932436140010
# To print values only
# 14916253649648110012114416919622525628932436140011
# To print values only
# 14916253649648110012114416919622525628932436140012
# To print values only
# 14916253649648110012114416919622525628932436140013
# To print values only
# 14916253649648110012114416919622525628932436140014
# To print values only
# 14916253649648110012114416919622525628932436140015
# To print values only
# 14916253649648110012114416919622525628932436140016
# To print values only
# 14916253649648110012114416919622525628932436140017
# To print values only
# 14916253649648110012114416919622525628932436140018
# To print values only
# 14916253649648110012114416919622525628932436140019
# To print values only
# 14916253649648110012114416919622525628932436140020
# To print values only
# 14916253649648110012114416919622525628932436140014 ==> 196
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562893243614002
# To print values only
# 1491625364964811001211441691962252562893243614003
# To print values only
# 1491625364964811001211441691962252562893243614004
# To print values only
# 1491625364964811001211441691962252562893243614005
# To print values only
# 1491625364964811001211441691962252562893243614006
# To print values only
# 1491625364964811001211441691962252562893243614007
# To print values only
# 1491625364964811001211441691962252562893243614008
# To print values only
# 1491625364964811001211441691962252562893243614009
# To print values only
# 14916253649648110012114416919622525628932436140010
# To print values only
# 14916253649648110012114416919622525628932436140011
# To print values only
# 14916253649648110012114416919622525628932436140012
# To print values only
# 14916253649648110012114416919622525628932436140013
# To print values only
# 14916253649648110012114416919622525628932436140014
# To print values only
# 14916253649648110012114416919622525628932436140015
# To print values only
# 14916253649648110012114416919622525628932436140016
# To print values only
# 14916253649648110012114416919622525628932436140017
# To print values only
# 14916253649648110012114416919622525628932436140018
# To print values only
# 14916253649648110012114416919622525628932436140019
# To print values only
# 14916253649648110012114416919622525628932436140020
# To print values only
# 14916253649648110012114416919622525628932436140015 ==> 225
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562893243614002
# To print values only
# 1491625364964811001211441691962252562893243614003
# To print values only
# 1491625364964811001211441691962252562893243614004
# To print values only
# 1491625364964811001211441691962252562893243614005
# To print values only
# 1491625364964811001211441691962252562893243614006
# To print values only
# 1491625364964811001211441691962252562893243614007
# To print values only
# 1491625364964811001211441691962252562893243614008
# To print values only
# 1491625364964811001211441691962252562893243614009
# To print values only
# 14916253649648110012114416919622525628932436140010
# To print values only
# 14916253649648110012114416919622525628932436140011
# To print values only
# 14916253649648110012114416919622525628932436140012
# To print values only
# 14916253649648110012114416919622525628932436140013
# To print values only
# 14916253649648110012114416919622525628932436140014
# To print values only
# 14916253649648110012114416919622525628932436140015
# To print values only
# 14916253649648110012114416919622525628932436140016
# To print values only
# 14916253649648110012114416919622525628932436140017
# To print values only
# 14916253649648110012114416919622525628932436140018
# To print values only
# 14916253649648110012114416919622525628932436140019
# To print values only
# 14916253649648110012114416919622525628932436140020
# To print values only
# 14916253649648110012114416919622525628932436140016 ==> 256
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562893243614002
# To print values only
# 1491625364964811001211441691962252562893243614003
# To print values only
# 1491625364964811001211441691962252562893243614004
# To print values only
# 1491625364964811001211441691962252562893243614005
# To print values only
# 1491625364964811001211441691962252562893243614006
# To print values only
# 1491625364964811001211441691962252562893243614007
# To print values only
# 1491625364964811001211441691962252562893243614008
# To print values only
# 1491625364964811001211441691962252562893243614009
# To print values only
# 14916253649648110012114416919622525628932436140010
# To print values only
# 14916253649648110012114416919622525628932436140011
# To print values only
# 14916253649648110012114416919622525628932436140012
# To print values only
# 14916253649648110012114416919622525628932436140013
# To print values only
# 14916253649648110012114416919622525628932436140014
# To print values only
# 14916253649648110012114416919622525628932436140015
# To print values only
# 14916253649648110012114416919622525628932436140016
# To print values only
# 14916253649648110012114416919622525628932436140017
# To print values only
# 14916253649648110012114416919622525628932436140018
# To print values only
# 14916253649648110012114416919622525628932436140019
# To print values only
# 14916253649648110012114416919622525628932436140020
# To print values only
# 14916253649648110012114416919622525628932436140017 ==> 289
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562893243614002
# To print values only
# 1491625364964811001211441691962252562893243614003
# To print values only
# 1491625364964811001211441691962252562893243614004
# To print values only
# 1491625364964811001211441691962252562893243614005
# To print values only
# 1491625364964811001211441691962252562893243614006
# To print values only
# 1491625364964811001211441691962252562893243614007
# To print values only
# 1491625364964811001211441691962252562893243614008
# To print values only
# 1491625364964811001211441691962252562893243614009
# To print values only
# 14916253649648110012114416919622525628932436140010
# To print values only
# 14916253649648110012114416919622525628932436140011
# To print values only
# 14916253649648110012114416919622525628932436140012
# To print values only
# 14916253649648110012114416919622525628932436140013
# To print values only
# 14916253649648110012114416919622525628932436140014
# To print values only
# 14916253649648110012114416919622525628932436140015
# To print values only
# 14916253649648110012114416919622525628932436140016
# To print values only
# 14916253649648110012114416919622525628932436140017
# To print values only
# 14916253649648110012114416919622525628932436140018
# To print values only
# 14916253649648110012114416919622525628932436140019
# To print values only
# 14916253649648110012114416919622525628932436140020
# To print values only
# 14916253649648110012114416919622525628932436140018 ==> 324
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562893243614002
# To print values only
# 1491625364964811001211441691962252562893243614003
# To print values only
# 1491625364964811001211441691962252562893243614004
# To print values only
# 1491625364964811001211441691962252562893243614005
# To print values only
# 1491625364964811001211441691962252562893243614006
# To print values only
# 1491625364964811001211441691962252562893243614007
# To print values only
# 1491625364964811001211441691962252562893243614008
# To print values only
# 1491625364964811001211441691962252562893243614009
# To print values only
# 14916253649648110012114416919622525628932436140010
# To print values only
# 14916253649648110012114416919622525628932436140011
# To print values only
# 14916253649648110012114416919622525628932436140012
# To print values only
# 14916253649648110012114416919622525628932436140013
# To print values only
# 14916253649648110012114416919622525628932436140014
# To print values only
# 14916253649648110012114416919622525628932436140015
# To print values only
# 14916253649648110012114416919622525628932436140016
# To print values only
# 14916253649648110012114416919622525628932436140017
# To print values only
# 14916253649648110012114416919622525628932436140018
# To print values only
# 14916253649648110012114416919622525628932436140019
# To print values only
# 14916253649648110012114416919622525628932436140020
# To print values only
# 14916253649648110012114416919622525628932436140019 ==> 361
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562893243614002
# To print values only
# 1491625364964811001211441691962252562893243614003
# To print values only
# 1491625364964811001211441691962252562893243614004
# To print values only
# 1491625364964811001211441691962252562893243614005
# To print values only
# 1491625364964811001211441691962252562893243614006
# To print values only
# 1491625364964811001211441691962252562893243614007
# To print values only
# 1491625364964811001211441691962252562893243614008
# To print values only
# 1491625364964811001211441691962252562893243614009
# To print values only
# 14916253649648110012114416919622525628932436140010
# To print values only
# 14916253649648110012114416919622525628932436140011
# To print values only
# 14916253649648110012114416919622525628932436140012
# To print values only
# 14916253649648110012114416919622525628932436140013
# To print values only
# 14916253649648110012114416919622525628932436140014
# To print values only
# 14916253649648110012114416919622525628932436140015
# To print values only
# 14916253649648110012114416919622525628932436140016
# To print values only
# 14916253649648110012114416919622525628932436140017
# To print values only
# 14916253649648110012114416919622525628932436140018
# To print values only
# 14916253649648110012114416919622525628932436140019
# To print values only
# 14916253649648110012114416919622525628932436140020
# To print values only
# 14916253649648110012114416919622525628932436140020 ==> 400
#
# To print key only
# 1
# To print values only
# 1491625364964811001211441691962252562893243614002
# To print values only
# 1491625364964811001211441691962252562893243614003
# To print values only
# 1491625364964811001211441691962252562893243614004
# To print values only
# 1491625364964811001211441691962252562893243614005
# To print values only
# 1491625364964811001211441691962252562893243614006
# To print values only
# 1491625364964811001211441691962252562893243614007
# To print values only
# 1491625364964811001211441691962252562893243614008
# To print values only
# 1491625364964811001211441691962252562893243614009
# To print values only
# 14916253649648110012114416919622525628932436140010
# To print values only
# 14916253649648110012114416919622525628932436140011
# To print values only
# 14916253649648110012114416919622525628932436140012
# To print values only
# 14916253649648110012114416919622525628932436140013
# To print values only
# 14916253649648110012114416919622525628932436140014
# To print values only
# 14916253649648110012114416919622525628932436140015
# To print values only
# 14916253649648110012114416919622525628932436140016
# To print values only
# 14916253649648110012114416919622525628932436140017
# To print values only
# 14916253649648110012114416919622525628932436140018
# To print values only
# 14916253649648110012114416919622525628932436140019
# To print values only
# 14916253649648110012114416919622525628932436140020
# To print values only
# 149162536496481100121144169196225256289324361400

# %% [markdown]
# Python program to convert 2 digit number   into words

# %%
d={0:'',1:'one',2:'two',3:'three',4:'four',5:'five',6:'six',7:'seven',8:'eight',9:'nine',\
10:'ten',11:'eleven',12:'twelve',13:'thirteen',14:'fourteen',15:'fifteen',16:'sixteen',\
17:'seventeen',18:'eightteen',19:'nineteen',20:'twenty',30:'thirty',40:'fourty',50:'fifty',\
60:'sixty',70:'seventy',80:'eighty',90:'ninty'}

num=int(input("Enter the integer between 1 to 99:"))
if (num<=20):
  print(d[num])
  if(num>20 and num<100):
    if num%10==0:       
      print(d[num])
    else:
      print(d[num//10*10]+""+d[num%10])
# Out:
# Enter the integer between 1 to 99:78

# %% [markdown]
# How to sort a dictionary by values in Python

# %%
d = {"Pierre": 42, "Anne": 33, "Zoe": 24}
#Use the sorted function and operator module
import operator
sorted_d = sorted(d.items(), key=operator.itemgetter(1))
print(sorted_d)
sorted_a= sorted(d.items(), key=operator.itemgetter(1),reverse=True)
print(sorted_a)
# Out:
# [('Zoe', 24), ('Anne', 33), ('Pierre', 42)]
# [('Pierre', 42), ('Anne', 33), ('Zoe', 24)]

# %% [markdown]
# Python Program to count the number of lines in a text file.

# %%
fname = input("Enter file name: ")
num_lines = 0
with open(fname, 'r') as f:
  for line in f:
    num_lines += 1
print("Number of lines:")
print(num_lines)

# %% [markdown]
# Python Program to count the number of words in a text file

# %%
fname = input("Enter file name: ")
num_words = 0
with open(fname, 'r') as f:
  for line in f:
    words = line.split()
    num_words += len(words)
    print("Number of words:")
    print(num_words)
# Out:
# Enter file name: out.txt
# Number of words:
# 2

# %% [markdown]
# Python Program to count the occurrences of a word in a text file

# %%
fname = input("Enter file name: ")
word=input("Enter word to be searched:")
k = 0

with open(fname, 'r') as f:
  for line in f:
    words = line.split()
    for i in words:
      if(i==word):
        k=k+1
        print("Occurrences of the word:")
        print(k)
# Out:
# Enter file name: foo.txt
# Enter word to be searched:hii
# Occurrences of the word:
# 1

# %% [markdown]
# Python Program to copy the contents of one file into another.

# %%
with open("foo.txt") as f:
  with open("out.txt", "w") as f1:
    for line in f:
      f1.write(line)

# %% [markdown]
# Python Program to read the contents of the file in reverse order.

# %%
filename=input("Enter file name: ")

with open (filename,'r') as f:
  for line in f:
    l=line.split()
    l.reverse() 
    st= "".join(l)
    print (st)
# Out:
# Enter file name: out.txt
# hellohii
